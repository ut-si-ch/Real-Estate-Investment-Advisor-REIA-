# %% [markdown]
# <div style="background-color:#0B3D91; padding:25px; border-radius:12px; color:white;">
#
# # 🏡 **Real Estate Investment Advisor**
# ### *Predicting Property Profitability & 5-Year Future Value*
#
# ---
#
# ![Python](https://img.shields.io/badge/Python-3.10-blue)
# ![ML](https://img.shields.io/badge/Machine%20Learning-Regression%20%7C%20Classification-green)
# ![Streamlit](https://img.shields.io/badge/Streamlit-Interactive%20App-orange)
# ![MLflow](https://img.shields.io/badge/MLflow-Experiment%20Tracking-purple)
# ![License](https://img.shields.io/badge/License-MIT-yellow)
#
# </div>
# ---

# %% [markdown]
# <div style="background-color:#F2C94C; padding:20px; border-radius:10px; color:#2F3A45;">
# <h2>🚨 Problem Statement</h2>
# </div>
#
# <div style="background-color:#FFFFFF; padding:20px; border-radius:10px; box-shadow:0 0 10px #d2d2d2;">
#
# Investors struggle to identify:
# - Which property is a **Good Investment**
# - What its **Value will be after 5 years**
#
# This project builds:
# - ✔ A Classification Model → *Good Investment*
# - ✔ A Regression Model → *Future Price (5Y)*
#
# </div>

# %% [markdown]
# <div style="background-color:#2F3A45; padding:20px; border-radius:10px; color:white;">
# <h2>🧠 Solution Overview</h2>
# </div>
#
# <div style="background-color:#FFFFFF; padding:22px; border-radius:10px; box-shadow:0 0 10px #cfcfcf;">
#
# ### ✔ Data Cleaning & Feature Engineering
# ### ✔ Exploratory Data Analysis
# ### ✔ Classification + Regression Models
# ### ✔ MLflow Tracking
# ### ✔ Streamlit Deployment
#
# </div>

# %% [markdown]
# <div style="background-color:#0B3D91; padding:20px; border-radius:10px; color:white;">
# <h2>💼 Business Impact</h2>
# </div>
#
# <div style="border-left:6px solid #F2C94C; background:#FFFFFF; padding:20px; border-radius:10px;">
#
# ### 📌 For Investors
# - Identify undervalued properties
# - Calculate long-term returns
#
# ### 📌 For Real Estate Companies
# - Automated valuation model (AVM)
# - AI-driven investment recommendation
#
# ### 📌 For Loan Providers
# - Better asset risk scoring
#
# </div>

# %% [markdown]
# <div style="background-color:#F2C94C; padding:20px; border-radius:10px; color:#2F3A45;">
# <h2>📂 Dataset Overview</h2>
# </div>
#
# <div style="background-color:#FFFFFF; padding:22px; border-radius:10px; box-shadow:0 0 12px #dcdcdc;">
#
# ### 🎯 Key Columns
# - `City`, `Locality`, `BHK`, `Size_in_SqFt`
# - `Price_in_Lakhs`, `Price_per_SqFt`
# - `Amenities`, `Security`, `Owner_Type`
#
# ### 🎯 Target Variables
# - `Good_Investment` → *Classification*
# - `Future_Price_5Y` → *Regression*
#
# </div>

# %% [markdown]
# <div style="background-color:#2F3A45; padding:20px; border-radius:10px; color:white;">
# <h2>🌍 Real-World Use Case</h2>
# </div>
#
# <div style="background-color:#FFFFFF; padding:24px; border-radius:10px; box-shadow:0 0 10px #d3d3d3;">
#
# A buyer wants to know if a **3 BHK flat in Bangalore** is a good investment.
# Our model analyzes:
# - Price trends
# - Locality score
# - Amenities
# - Price per Sq.Ft
# - Future appreciation
#
# **Output:**
# ✔ *Good Investment: YES*
# ✔ *Estimated 5Y Price: ₹89 Lakhs*
#
# </div>

# %% [markdown]
# <div style="background-color:#0B3D91; padding:20px; border-radius:10px; color:white;">
# <h2>🔗 Project Resources</h2>
# </div>
#
# <div style="background-color:#FFFFFF; padding:20px; border-radius:10px; box-shadow:0 0 8px #cfcfcf;">
#
# ### 🐙 [GitHub Repo](https://github.com/ut-si-ch/Real-Estate-Investment-Advisor-REIA-.git)
#
# ### 💼 [LinkedIn Connect](https://www.linkedin.com/in/uttam-singh-chaudhary-98408214b)
#
# ### 🌐 [Portfolio Page](https://datascienceportfol.io/uttamsinghchaudhary)
#
# ### 🎥 Demo Video
#
# </div>

# %% [markdown]
# <div style="background-color:#F2C94C; padding:25px; border-radius:12px; color:#2F3A45; text-align:center">
# <h1>🚀 Let's Start Coding!</h1>
# <h3>Your Real Estate ML Pipeline begins below.</h3>
# </div>
